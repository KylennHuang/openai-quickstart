# %% [markdown]
# ### 1. 询问业务相关的问题（能从数据库找到回答）
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. 询问业务相关的问题（无法从数据库找到回答）
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. 询问跟业务无关的问题（未使用历史聊天记录）
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 4. 询问跟业务无关的问题（使用历史聊天记录）
# ![image.png](attachment:image.png)
